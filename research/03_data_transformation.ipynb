# %%
import os

# %%
# %pwd
# Out:
# '/Users/jaykhakhar/Downloads/Mlprojects/End-to-end-Machine-Learning-Project-with-MLflow/research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/Users/jaykhakhar/Downloads/Mlprojects/End-to-end-Machine-Learning-Project-with-MLflow'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir:Path
    data_path: Path

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self)-> DataTransformationConfig:
        config= self.config.data_transformation

        create_directories([config.root_dir])
        data_transformation_config= DataTransformationConfig(
            root_dir=config.root_dir,
            data_path= config.data_path,
        )

        return data_transformation_config

# %%
import os
from mlProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self,config: DataTransformationConfig):
        self.config = config

    def train_test_spliting(self):
        data=pd.read_csv(self.config.data_path)
        train, test= train_test_split(data)
        train.to_csv(os.path.join(self.config.root_dir,"train.csv"),index=False)
        test.to_csv(os.path.join(self.config.root_dir,"test.csv"),index=False)
        logger.info("splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [2026-03-19 03:22:21,866: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2026-03-19 03:22:21,868: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-03-19 03:22:21,869: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-03-19 03:22:21,870: INFO: common: created directory at: artifacts]
# [2026-03-19 03:22:21,871: INFO: common: created directory at: artifacts/data_transformation]
# [2026-03-19 03:22:21,896: INFO: 287034178: splited data into training and test sets]
# [2026-03-19 03:22:21,897: INFO: 287034178: (1199, 12)]
# [2026-03-19 03:22:21,897: INFO: 287034178: (400, 12)]
# (1199, 12)
# (400, 12)

# %%
from pathlib import Path
print("File exists:", Path("artifacts/data_ingestion/winequality-red.csv").exists())
# Out:
# File exists: False

# %%
from pathlib import Path
print(Path("artifacts/data_ingestion/winequality-red.csv").exists())
# Out:
# False

# %%
from mlProject.utils.common import read_yaml
from pathlib import Path

config = read_yaml(Path("config/config.yaml"))

print("Keys in config:", config.keys())
# Out:
# [2026-03-19 02:45:08,162: INFO: common: yaml file: config/config.yaml loaded successfully]
# Keys in config: dict_keys(['artifacts_root', 'data_ingestion', 'data_validation', 'data_transformation', 'model_trainer', 'model_evaluation'])

# %%
import os
print(os.listdir("artifacts/data_transformation"))
# Out:
# []

# %%
import os
import sys
from pathlib import Path

project_root = Path("/Users/jaykhakhar/Downloads/Mlprojects/End-to-end-Machine-Learning-Project-with-MLflow")

os.chdir(project_root)
sys.path.append(str(project_root / "src"))

print("Working directory:", os.getcwd())
# Out:
# Working directory: /Users/jaykhakhar/Downloads/Mlprojects/End-to-end-Machine-Learning-Project-with-MLflow

# %%
from pathlib import Path
print(Path("artifacts/data_ingestion/winequality-red.csv").exists())
# Out:
# True

# %%
from mlProject.pipeline.stage_01_data_ingestion import DataIngestionTrainingPipeline

obj = DataIngestionTrainingPipeline()
obj.main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from mlProject.pipeline.stage_01_data_ingestion import DataIngestionTrainingPipeline
#       3 obj = DataIngestionTrainingPipeline()
#       4 obj.main()
#
# File ~/Downloads/Mlprojects/End-to-end-Machine-Learning-Project-with-MLflow/src/mlProject/pipeline/stage_01_data_ingestion.py:1
# ----> 1 from mlProject.config.configuration import ConfigurationManager
#       2 from mlProject.components.data_ingestion import DataIngestion
#       3 from mlProject import logger
#
# File ~/Downloads/Mlprojects/End-to-end-Machine-Learning-Project-with-MLflow/src/mlProject/config/configuration.py:3
#       1 from mlProject.constants import *
#       2 from mlProject.utils.common import read_yaml, create_directories
# ----> 3 from mlProject.entity.config_entity import (DataIngestionConfig,
#       4                                             DataValidationConfig,
#       5                                             DataTransformationConfig)
#       7 class ConfigurationManager:
#       8     def __init__(
#       9         self,
#      10         config_filepath = CONFIG_FILE_PATH,
#      11         params_filepath = PARAMS_FILE_PATH,
#      12         schema_filepath = SCHEMA_FILE_PATH):
#
# ImportError: cannot import name 'DataTransformationConfig' from 'mlProject.entity.config_entity' (/Users/jaykhakhar/Downloads/Mlprojects/End-to-end-Machine-Learning-Project-with-MLflow/src/mlProject/entity/config_entity.py)
